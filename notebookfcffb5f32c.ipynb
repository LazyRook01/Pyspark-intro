# %%
import pandas as pd

# Load the data from 'corn.pkl' into a DataFrame
corn_df = pd.read_pickle('/kaggle/input/crop-yield/corn.pkl')

# Load the data from 'soybean.pkl' into a DataFrame
soybean_df = pd.read_pickle('/kaggle/input/crop-yield/soybean.pkl')

# %%
# Set the maximum number of rows to display
pd.set_option('display.max_rows', None)

# Calculate the number of missing values in each column
missing_values_corn = corn_df.isnull().sum()

# Print the missing values
print(missing_values_corn)
# Out:
# Year                                   0
# state                                  0
# max_humidity 1                         0
# max_humidity 2                         0
# max_humidity 3                         0
# max_humidity 4                         0
# max_humidity 5                         0
# max_humidity 6                         0
# max_humidity 7                         0
# max_humidity 8                         0
# max_humidity 9                         0
# max_humidity 10                        0
# max_humidity 11                        0
# max_humidity 12                        0
# max_humidity 13                        0
# max_humidity 14                        0
# max_humidity 15                        0
# max_humidity 16                        0
# max_humidity 17                        0
# max_humidity 18                        0
# max_humidity 19                        0
# max_humidity 20                        0
# max_humidity 21                        0
# max_humidity 22                        0
# max_humidity 23                        0
# max_humidity 24                        0
# max_humidity 25                        0
# max_humidity 26                        0
# max_humidity 27                        0
# max_humidity 28                        0
# max_humidity 29                        0
# max_humidity 30                        0
# max_humidity 31                        0
# max_humidity 32                        0
# max_humidity 33                        0
# max_humidity 34                        0
# max_humidity 35                        0
# max_humidity 36                        0
# max_humidity 37                        0
# max_humidity 38                        0
# max_humidity 39                        0
# max_humidity 40                        0
# max_humidity 41                        0
# max_humidity 42                        0
# max_humidity 43                        0
# max_humidity 44                        0
# max_humidity 45                        0
# max_humidity 46                        0
# max_humidity 47                        0
# max_humidity 48                        0
# max_humidity 49                        0
# max_humidity 50                        0
# max_humidity 51                        0
# max_humidity 52                        0
# max_humidity 53                      338
# max_temp 1                             0
# max_temp 2                             0
# max_temp 3                             0
# max_temp 4                             0
# max_temp 5                             0
# max_temp 6                             0
# max_temp 7                             0
# max_temp 8                             0
# max_temp 9                             0
# max_temp 10                            0
# max_temp 11                            0
# max_temp 12                            0
# max_temp 13                            0
# max_temp 14                            0
# max_temp 15                            0
# max_temp 16                            0
# max_temp 17                            0
# max_temp 18                            0
# max_temp 19                            0
# max_temp 20                            0
# max_temp 21                            0
# max_temp 22                            0
# max_temp 23                            0
# max_temp 24                            0
# max_temp 25                            0
# max_temp 26                            0
# max_temp 27                            0
# max_temp 28                            0
# max_temp 29                            0
# max_temp 30                            0
# max_temp 31                            0
# max_temp 32                            0
# max_temp 33                            0
# max_temp 34                            0
# max_temp 35                            0
# max_temp 36                            0
# max_temp 37                            0
# max_temp 38                            0
# max_temp 39                            0
# max_temp 40                            0
# max_temp 41                            0
# max_temp 42                            0
# max_temp 43                            0
# max_temp 44                            0
# max_temp 45                            0
# max_temp 46                            0
# max_temp 47                            0
# max_temp 48                            0
# max_temp 49                            0
# max_temp 50                            0
# max_temp 51                            0
# max_temp 52                            0
# max_temp 53                          338
# min_humidity 1                         0
# min_humidity 2                         0
# min_humidity 3                         0
# min_humidity 4                         0
# min_humidity 5                         0
# min_humidity 6                         0
# min_humidity 7                         0
# min_humidity 8                         0
# min_humidity 9                         0
# min_humidity 10                        0
# min_humidity 11                        0
# min_humidity 12                        0
# min_humidity 13                        0
# min_humidity 14                        0
# min_humidity 15                        0
# min_humidity 16                        0
# min_humidity 17                        0
# min_humidity 18                        0
# min_humidity 19                        0
# min_humidity 20                        0
# min_humidity 21                        0
# min_humidity 22                        0
# min_humidity 23                        0
# min_humidity 24                        0
# min_humidity 25                        0
# min_humidity 26                        0
# min_humidity 27                        0
# min_humidity 28                        0
# min_humidity 29                        0
# min_humidity 30                        0
# min_humidity 31                        0
# min_humidity 32                        0
# min_humidity 33                        0
# min_humidity 34                        0
# min_humidity 35                        0
# min_humidity 36                        0
# min_humidity 37                        0
# min_humidity 38                        0
# min_humidity 39                        0
# min_humidity 40                        0
# min_humidity 41                        0
# min_humidity 42                        0
# min_humidity 43                        0
# min_humidity 44                        0
# min_humidity 45                        0
# min_humidity 46                        0
# min_humidity 47                        0
# min_humidity 48                        0
# min_humidity 49                        0
# min_humidity 50                        0
# min_humidity 51                        0
# min_humidity 52                        0
# min_humidity 53                      338
# min_temp 1                             0
# min_temp 2                             0
# min_temp 3                             0
# min_temp 4                             0
# min_temp 5                             0
# min_temp 6                             0
# min_temp 7                             0
# min_temp 8                             0
# min_temp 9                             0
# min_temp 10                            0
# min_temp 11                            0
# min_temp 12                            0
# min_temp 13                            0
# min_temp 14                            0
# min_temp 15                            0
# min_temp 16                            0
# min_temp 17                            0
# min_temp 18                            0
# min_temp 19                            0
# min_temp 20                            0
# min_temp 21                            0
# min_temp 22                            0
# min_temp 23                            0
# min_temp 24                            0
# min_temp 25                            0
# min_temp 26                            0
# min_temp 27                            0
# min_temp 28                            0
# min_temp 29                            0
# min_temp 30                            0
# min_temp 31                            0
# min_temp 32                            0
# min_temp 33                            0
# min_temp 34                            0
# min_temp 35                            0
# min_temp 36                            0
# min_temp 37                            0
# min_temp 38                            0
# min_temp 39                            0
# min_temp 40                            0
# min_temp 41                            0
# min_temp 42                            0
# min_temp 43                            0
# min_temp 44                            0
# min_temp 45                            0
# min_temp 46                            0
# min_temp 47                            0
# min_temp 48                            0
# min_temp 49                            0
# min_temp 50                            0
# min_temp 51                            0
# min_temp 52                            0
# min_temp 53                          338
# near_surface_specific_humidity 1       0
# near_surface_specific_humidity 2       0
# near_surface_specific_humidity 3       0
# near_surface_specific_humidity 4       0
# near_surface_specific_humidity 5       0
# near_surface_specific_humidity 6       0
# near_surface_specific_humidity 7       0
# near_surface_specific_humidity 8       0
# near_surface_specific_humidity 9       0
# near_surface_specific_humidity 10      0
# near_surface_specific_humidity 11      0
# near_surface_specific_humidity 12      0
# near_surface_specific_humidity 13      0
# near_surface_specific_humidity 14      0
# near_surface_specific_humidity 15      0
# near_surface_specific_humidity 16      0
# near_surface_specific_humidity 17      0
# near_surface_specific_humidity 18      0
# near_surface_specific_humidity 19      0
# near_surface_specific_humidity 20      0
# near_surface_specific_humidity 21      0
# near_surface_specific_humidity 22      0
# near_surface_specific_humidity 23      0
# near_surface_specific_humidity 24      0
# near_surface_specific_humidity 25      0
# near_surface_specific_humidity 26      0
# near_surface_specific_humidity 27      0
# solar_radiation 43                     0
# solar_radiation 44                     0
# solar_radiation 45                     0
# solar_radiation 46                     0
# solar_radiation 47                     0
# solar_radiation 48                     0
# solar_radiation 49                     0
# solar_radiation 50                     0
# solar_radiation 51                     0
# solar_radiation 52                     0
# solar_radiation 53                   338
# vapor_pressure_deficit 1               0
# vapor_pressure_deficit 2               0
# vapor_pressure_deficit 3               0
# vapor_pressure_deficit 4               0
# vapor_pressure_deficit 5               0
# vapor_pressure_deficit 6               0
# vapor_pressure_deficit 7               0
# vapor_pressure_deficit 8               0
# vapor_pressure_deficit 9               0
# vapor_pressure_deficit 10              0
# vapor_pressure_deficit 11              0
# vapor_pressure_deficit 12              0
# vapor_pressure_deficit 13              0
# vapor_pressure_deficit 14              0
# vapor_pressure_deficit 15              0
# vapor_pressure_deficit 16              0
# vapor_pressure_deficit 17              0
# vapor_pressure_deficit 18              0
# vapor_pressure_deficit 19              0
# vapor_pressure_deficit 20              0
# vapor_pressure_deficit 21              0
# vapor_pressure_deficit 22              0
# vapor_pressure_deficit 23              0
# vapor_pressure_deficit 24              0
# vapor_pressure_deficit 25              0
# vapor_pressure_deficit 26              0
# vapor_pressure_deficit 27              0
# vapor_pressure_deficit 28              0
# vapor_pressure_deficit 29              0
# vapor_pressure_deficit 30              0
# vapor_pressure_deficit 31              0
# vapor_pressure_deficit 32              0
# vapor_pressure_deficit 33              0
# vapor_pressure_deficit 34              0
# vapor_pressure_deficit 35              0
# vapor_pressure_deficit 36              0
# vapor_pressure_deficit 37              0
# vapor_pressure_deficit 38              0
# vapor_pressure_deficit 39              0
# vapor_pressure_deficit 40              0
# vapor_pressure_deficit 41              0
# vapor_pressure_deficit 42              0
# vapor_pressure_deficit 43              0
# vapor_pressure_deficit 44              0
# vapor_pressure_deficit 45              0
# vapor_pressure_deficit 46              0
# vapor_pressure_deficit 47              0
# vapor_pressure_deficit 48              0
# vapor_pressure_deficit 49              0
# vapor_pressure_deficit 50              0
# vapor_pressure_deficit 51              0
# vapor_pressure_deficit 52              0
# vapor_pressure_deficit 53            338
# wind_speed 1                           0
# wind_speed 2                           0
# wind_speed 3                           0
# wind_speed 4                           0
# wind_speed 5                           0
# wind_speed 6                           0
# wind_speed 7                           0
# wind_speed 8                           0
# wind_speed 9                           0
# wind_speed 10                          0
# wind_speed 11                          0
# wind_speed 12                          0
# wind_speed 13                          0
# wind_speed 14                          0
# wind_speed 15                          0
# wind_speed 16                          0
# wind_speed 17                          0
# wind_speed 18                          0
# wind_speed 19                          0
# wind_speed 20                          0
# wind_speed 21                          0
# wind_speed 22                          0
# wind_speed 23                          0
# wind_speed 24                          0
# wind_speed 25                          0
# wind_speed 26                          0
# wind_speed 27                          0
# wind_speed 28                          0
# wind_speed 29                          0
# wind_speed 30                          0
# wind_speed 31                          0
# wind_speed 32                          0
# wind_speed 33                          0
# wind_speed 34                          0
# wind_speed 35                          0
# wind_speed 36                          0
# wind_speed 37                          0
# wind_speed 38                          0
# wind_speed 39                          0
# wind_speed 40                          0
# wind_speed 41                          0
# wind_speed 42                          0
# wind_speed 43                          0
# wind_speed 44                          0
# wind_speed 45                          0
# wind_speed 46                          0
# wind_speed 47                          0
# wind_speed 48                          0
# wind_speed 49                          0
# wind_speed 50                          0
# wind_speed 51                          0
# wind_speed 52                          0
# wind_speed 53                        338
# Corn_Yield                             0
# dtype: int64

# %%
# Filter the columns containing '53' in their names
columns_to_drop = [col for col in corn_df.columns if '53' in col]

# Drop the columns
corn_df = corn_df.drop(columns=columns_to_drop)

# %%
corn_df.shape
# Out:
# (533, 471)

# %%
pip install pycaret[full]
# Out:
# Collecting pycaret[full]
#   Downloading pycaret-3.1.0-py3-none-any.whl (483 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.5.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (8.14.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (4.66.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.23.5)
# Collecting pandas<2.0.0,>=1.3.0 (from pycaret[full])
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=1.2 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.1.2)
# Collecting scipy~=1.10.1 (from pycaret[full])
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.3.2)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.2.2)
# Collecting pyod>=1.0.8 (from pycaret[full])
#   Downloading pyod-1.1.1.tar.gz (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 15.3 MB/s eta 0:00:00
# done
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.11.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.6.2)
# Requirement already satisfied: lightgbm>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.3.2)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.57.1)
# Requirement already satisfied: requests>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (5.9.3)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.1.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (6.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (5.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.1.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.7.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.5)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (5.15.0)
# Collecting kaleido>=0.2.1 (from pycaret[full])
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 14.1 MB/s eta 0:00:00
# Collecting schemdraw==0.15 (from pycaret[full])
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.8 MB/s eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1 (from pycaret[full])
#   Downloading plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.14.0)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 (from pycaret[full])
#   Downloading sktime-0.21.1-py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 30.1 MB/s eta 0:00:00
# Collecting tbats>=1.1.3 (from pycaret[full])
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.0 MB/s eta 0:00:00
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0 (from pycaret[full])
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 75.9 MB/s eta 0:00:00
# Requirement already satisfied: wurlitzer in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.0.3)
# Requirement already satisfied: shap>=0.38.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.42.1)
# Collecting interpret>=0.2.7 (from pycaret[full])
#   Downloading interpret-0.4.4-py3-none-any.whl (1.4 kB)
# Requirement already satisfied: umap-learn>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.5.3)
# Requirement already satisfied: ydata-profiling>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (4.3.1)
# Collecting explainerdashboard>=0.3.8 (from pycaret[full])
#   Downloading explainerdashboard-0.4.3-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 kB 23.4 MB/s eta 0:00:00
# Collecting Flask==2.2.3 (from pycaret[full])
#   Downloading Flask-2.2.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.1 MB/s eta 0:00:00
# Collecting fairlearn==0.7.0 (from pycaret[full])
#   Downloading fairlearn-0.7.0-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: xgboost>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.7.6)
# Requirement already satisfied: kmodes>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.12.2)
# Requirement already satisfied: mlxtend>=0.19.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.22.0)
# Collecting statsforecast<1.6.0,>=0.5.5 (from pycaret[full])
#   Downloading statsforecast-1.5.0-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 10.3 MB/s eta 0:00:00
# Collecting tune-sklearn>=0.2.1 (from pycaret[full])
#   Downloading tune_sklearn-0.4.6-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: ray[tune]>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2.5.1)
# Requirement already satisfied: hyperopt>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.2.7)
# Requirement already satisfied: optuna>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (3.3.0)
# Requirement already satisfied: scikit-optimize>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.9.0)
# Collecting mlflow<2.0.0,>=1.24.0 (from pycaret[full])
#   Downloading mlflow-1.30.1-py3-none-any.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 67.8 MB/s eta 0:00:00
# Collecting gradio>=2.8.10 (from pycaret[full])
#   Downloading gradio-3.50.2-py3-none-any.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: boto3>=1.24.56 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.26.100)
# Requirement already satisfied: fastapi>=0.75.0 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.98.0)
# Requirement already satisfied: uvicorn>=0.17.6 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (0.22.0)
# Collecting m2cgen>=0.9.0 (from pycaret[full])
#   Downloading m2cgen-0.10.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 10.0 MB/s eta 0:00:00
# Collecting evidently<0.3,>=0.1.45.dev0 (from pycaret[full])
#   Downloading evidently-0.2.8-py3-none-any.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 81.2 MB/s eta 0:00:00
# Collecting fugue>=0.8.0 (from pycaret[full])
#   Downloading fugue-0.8.6-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.0/275.0 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: pytest>=7.0.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (7.4.1)
# Collecting moto>=3.0.7 (from pycaret[full])
#   Downloading moto-4.2.7-py2.py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 83.8 MB/s eta 0:00:00
# Collecting dash[testing] (from pycaret[full])
#   Downloading dash-2.14.1-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 93.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn-intelex>=2023.0.1 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (2023.2.1)
# Requirement already satisfied: catboost>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from pycaret[full]) (1.2.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /opt/conda/lib/python3.10/site-packages (from Flask==2.2.3->pycaret[full]) (2.3.7)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/lib/python3.10/site-packages (from Flask==2.2.3->pycaret[full]) (2.1.2)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.10/site-packages (from Flask==2.2.3->pycaret[full]) (8.1.7)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3>=1.24.56->pycaret[full])
#   Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.24.56->pycaret[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.24.56->pycaret[full]) (0.6.2)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost>=0.23.2->pycaret[full]) (0.20.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost>=0.23.2->pycaret[full]) (1.16.0)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from category-encoders>=2.4.0->pycaret[full]) (0.5.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from deprecation>=2.1.0->pycaret[full]) (21.3)
# Collecting nltk>=3.6.7 (from evidently<0.3,>=0.1.45.dev0->pycaret[full])
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 58.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/lib/python3.10/site-packages (from evidently<0.3,>=0.1.45.dev0->pycaret[full]) (6.0)
# Requirement already satisfied: pydantic<2 in /opt/conda/lib/python3.10/site-packages (from evidently<0.3,>=0.1.45.dev0->pycaret[full]) (1.10.9)
# Collecting dash-auth (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading dash_auth-2.0.0-py3-none-any.whl (3.4 kB)
# Collecting dash-bootstrap-components>=1 (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading dash_bootstrap_components-1.5.0-py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.2/221.2 kB 19.9 MB/s eta 0:00:00
# Collecting dtreeviz>=2.1 (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading dtreeviz-2.2.2-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 9.2 MB/s eta 0:00:00
# Collecting flask-simplelogin (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading flask_simplelogin-0.1.2-py3-none-any.whl (7.2 kB)
# Collecting Flask-WTF>=1.1 (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Collecting jupyter-dash>=0.4.1 (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting oyaml (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Collecting waitress (from explainerdashboard>=0.3.8->pycaret[full])
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi>=0.75.0->pycaret[full]) (0.27.0)
# Collecting triad>=0.9.1 (from fugue>=0.8.0->pycaret[full])
#   Downloading triad-0.9.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.2 MB/s eta 0:00:00
# Collecting adagio>=0.2.4 (from fugue>=0.8.0->pycaret[full])
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: pyarrow>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.0->pycaret[full]) (9.0.0)
# Collecting qpd>=0.4.4 (from fugue>=0.8.0->pycaret[full])
#   Downloading qpd-0.4.4-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 14.6 MB/s eta 0:00:00
# Collecting fugue-sql-antlr>=0.1.6 (from fugue>=0.8.0->pycaret[full])
#   Downloading fugue-sql-antlr-0.1.8.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 15.1 MB/s eta 0:00:00
# done
# Requirement already satisfied: sqlglot in /opt/conda/lib/python3.10/site-packages (from fugue>=0.8.0->pycaret[full]) (17.16.2)
# Collecting dask[dataframe,distributed]<2023.7.1,>=2022.9.0 (from fugue>=0.8.0->pycaret[full])
#   Downloading dask-2023.7.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (5.1.1)
# Collecting ffmpy (from gradio>=2.8.10->pycaret[full])
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.6.1 (from gradio>=2.8.10->pycaret[full])
#   Downloading gradio_client-0.6.1-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 24.0 MB/s eta 0:00:00
# Collecting httpx (from gradio>=2.8.10->pycaret[full])
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (0.16.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (5.12.0)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (3.9.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (9.5.0)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (0.25.1)
# Collecting python-multipart (from gradio>=2.8.10->pycaret[full])
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.8 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio>=2.8.10->pycaret[full])
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (4.6.3)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio>=2.8.10->pycaret[full]) (11.0.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.6.1->gradio>=2.8.10->pycaret[full]) (2023.9.0)
# Requirement already satisfied: networkx>=2.2 in /opt/conda/lib/python3.10/site-packages (from hyperopt>=0.2.7->pycaret[full]) (3.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from hyperopt>=0.2.7->pycaret[full]) (0.18.3)
# Requirement already satisfied: py4j in /opt/conda/lib/python3.10/site-packages (from hyperopt>=0.2.7->pycaret[full]) (0.10.9.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.8.1->pycaret[full]) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.12.0->pycaret[full]) (3.15.0)
# Collecting interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4 (from interpret>=0.2.7->pycaret[full])
#   Downloading interpret_core-0.4.4-py3-none-any.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 74.1 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.10.0 in /opt/conda/lib/python3.10/site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (6.23.3)
# Collecting SALib>=1.3.3 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading salib-1.4.7-py3-none-any.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 kB 46.3 MB/s eta 0:00:00
# Collecting treeinterpreter>=0.2.2 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Requirement already satisfied: dill>=0.2.5 in /opt/conda/lib/python3.10/site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (0.3.7)
# Collecting skope-rules>=1.0.1 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: lime>=0.1.1.33 in /opt/conda/lib/python3.10/site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (0.2.0.1)
# Collecting dash-core-components>=1.0.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components>=1.0.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table>=4.1.0 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading dash_cytoscape-0.3.0-py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 89.2 MB/s eta 0:00:00
# Collecting gevent>=1.3.6 (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading gevent-23.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 87.2 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (2.15.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=5.5.0->pycaret[full]) (4.8.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.5->pycaret[full]) (3.0.7)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm>=3.0.0->pycaret[full]) (0.40.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->pycaret[full]) (2.8.2)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (3.1.31)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (3.20.3)
# Collecting pytz<2023 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 33.2 MB/s eta 0:00:00
# Collecting importlib-metadata>=4.12.0 (from pycaret[full])
#   Downloading importlib_metadata-5.2.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (0.4.4)
# Requirement already satisfied: alembic<2 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (1.12.0)
# Requirement already satisfied: docker<7,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow<2.0.0,>=1.24.0->pycaret[full]) (6.1.3)
# Collecting prometheus-flask-exporter<1 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading prometheus_flask_exporter-0.23.0-py3-none-any.whl (18 kB)
# Collecting querystring-parser<2 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting sqlalchemy<2,>=1.4.0 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading SQLAlchemy-1.4.50-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.1 MB/s eta 0:00:00
# Collecting gunicorn<21 (from mlflow<2.0.0,>=1.24.0->pycaret[full])
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from mlxtend>=0.19.0->pycaret[full]) (68.0.0)
# Requirement already satisfied: cryptography>=3.3.1 in /opt/conda/lib/python3.10/site-packages (from moto>=3.0.7->pycaret[full]) (38.0.4)
# Collecting xmltodict (from moto>=3.0.7->pycaret[full])
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: responses>=0.13.0 in /opt/conda/lib/python3.10/site-packages (from moto>=3.0.7->pycaret[full]) (0.18.0)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret[full]) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret[full]) (4.17.3)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.2.0->pycaret[full]) (5.3.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.55.0->pycaret[full]) (0.40.1)
# Requirement already satisfied: cmaes>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=3.0.0->pycaret[full]) (0.10.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna>=3.0.0->pycaret[full]) (6.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=5.0.0->pycaret[full]) (8.2.2)
# Collecting trace-updater>=0.0.8 (from plotly-resampler>=0.8.3.1->pycaret[full])
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 18.2 MB/s eta 0:00:00
# Collecting tsdownsample==0.1.2 (from plotly-resampler>=0.8.3.1->pycaret[full])
#   Downloading tsdownsample-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.3 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (0.29.35)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (1.26.15)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.10/site-packages (from pytest>=7.0.1->pycaret[full]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/lib/python3.10/site-packages (from pytest>=7.0.1->pycaret[full]) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/conda/lib/python3.10/site-packages (from pytest>=7.0.1->pycaret[full]) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pytest>=7.0.1->pycaret[full]) (2.0.1)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (23.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (3.12.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.0.5)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.3.3)
# Requirement already satisfied: grpcio<=1.51.3,>=1.42.0 in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.51.3)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/conda/lib/python3.10/site-packages (from ray[tune]>=1.0.0->pycaret[full]) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret[full]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret[full]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.27.1->pycaret[full]) (2023.7.22)
# Requirement already satisfied: daal4py==2023.2.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn-intelex>=2023.0.1->pycaret[full]) (2023.2.1)
# Requirement already satisfied: daal==2023.2.1 in /opt/conda/lib/python3.10/site-packages (from daal4py==2023.2.1->scikit-learn-intelex>=2023.0.1->pycaret[full]) (2023.2.1)
# Requirement already satisfied: tbb==2021.* in /opt/conda/lib/python3.10/site-packages (from daal==2023.2.1->daal4py==2023.2.1->scikit-learn-intelex>=2023.0.1->pycaret[full]) (2021.10.0)
# Requirement already satisfied: pyaml>=16.9 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize>=0.9.0->pycaret[full]) (23.9.1)
# Requirement already satisfied: slicer==0.0.7 in /opt/conda/lib/python3.10/site-packages (from shap>=0.38.0->pycaret[full]) (0.0.7)
# Requirement already satisfied: deprecated>=1.2.13 in /opt/conda/lib/python3.10/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret[full]) (1.2.14)
# Collecting scikit-base<0.6.0 (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret[full])
#   Downloading scikit_base-0.5.2-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.10/site-packages (from umap-learn>=0.5.2->pycaret[full]) (0.5.10)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.17.6->pycaret[full]) (0.14.0)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.12.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.9.1)
# Requirement already satisfied: typeguard<3,>=2.13.2 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in /opt/conda/lib/python3.10/site-packages (from ydata-profiling>=4.3.1->pycaret[full]) (1.8.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling>=4.3.1->pycaret[full]) (1.4.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /opt/conda/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling>=4.3.1->pycaret[full]) (0.2.0)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dash[testing]->pycaret[full]) (1.3.3)
# Collecting ansi2html (from dash[testing]->pycaret[full])
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from dash[testing]->pycaret[full]) (1.5.6)
# Requirement already satisfied: beautifulsoup4>=4.8.2 in /opt/conda/lib/python3.10/site-packages (from dash[testing]->pycaret[full]) (4.12.2)
# Requirement already satisfied: lxml>=4.6.2 in /opt/conda/lib/python3.10/site-packages (from dash[testing]->pycaret[full]) (4.9.3)
# Collecting percy>=2.0.2 (from dash[testing]->pycaret[full])
#   Downloading percy-2.0.2-py2.py3-none-any.whl (12 kB)
# Collecting selenium<=4.2.0,>=3.141.0 (from dash[testing]->pycaret[full])
#   Downloading selenium-4.2.0-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 52.0 MB/s eta 0:00:00
# Requirement already satisfied: multiprocess>=0.70.12 in /opt/conda/lib/python3.10/site-packages (from dash[testing]->pycaret[full]) (0.70.15)
# Collecting dash-testing-stub>=0.0.2 (from dash[testing]->pycaret[full])
#   Downloading dash_testing_stub-0.0.2-py3-none-any.whl (2.6 kB)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic<2->mlflow<2.0.0,>=1.24.0->pycaret[full]) (1.2.4)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio>=2.8.10->pycaret[full]) (0.12.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.8.2->dash[testing]->pycaret[full]) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.3.1->moto>=3.0.7->pycaret[full]) (1.15.1)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (1.4.0)
# Collecting distributed==2023.7.0 (from dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full])
#   Downloading distributed-2023.7.0-py3-none-any.whl (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.6/981.6 kB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: locket>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (1.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /opt/conda/lib/python3.10/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (2.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /opt/conda/lib/python3.10/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (6.3.2)
# Requirement already satisfied: zict>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from distributed==2023.7.0->dask[dataframe,distributed]<2023.7.1,>=2022.9.0->fugue>=0.8.0->pycaret[full]) (3.0.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow<2.0.0,>=1.24.0->pycaret[full]) (2.7.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow<2.0.0,>=1.24.0->pycaret[full]) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow<2.0.0,>=1.24.0->pycaret[full]) (0.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret[full]) (1.14.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/conda/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow<2.0.0,>=1.24.0->pycaret[full]) (1.6.0)
# Collecting colour (from dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[full])
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting wtforms (from Flask-WTF>=1.1->explainerdashboard>=0.3.8->pycaret[full])
#   Downloading wtforms-3.1.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.2/145.2 kB 14.1 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime<4.12 (from fugue-sql-antlr>=0.1.6->fugue>=0.8.0->pycaret[full])
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow<2.0.0,>=1.24.0->pycaret[full]) (4.0.10)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (7.4.9)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.10.0->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[full]) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret[full]) (3.10.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>=3.6.7->evidently<0.3,>=0.1.45.dev0->pycaret[full]) (2023.6.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret[full]) (0.7.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from prometheus-flask-exporter<1->mlflow<2.0.0,>=1.24.0->pycaret[full]) (0.17.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret[full]) (0.2.6)
# Collecting trio~=0.17 (from selenium<=4.2.0,>=3.141.0->dash[testing]->pycaret[full])
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 33.8 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium<=4.2.0,>=3.141.0->dash[testing]->pycaret[full])
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<2,>=1.4.0->mlflow<2.0.0,>=1.24.0->pycaret[full]) (2.0.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.75.0->pycaret[full]) (3.7.0)
# Collecting fs (from triad>=0.9.1->fugue>=0.8.0->pycaret[full])
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.5.4)
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx->gradio>=2.8.10->pycaret[full])
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio>=2.8.10->pycaret[full]) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=5.5.0->pycaret[full]) (0.2.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.1->moto>=3.0.7->pycaret[full]) (2.21)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full])
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow<2.0.0,>=1.24.0->pycaret[full]) (5.0.0)
# Requirement already satisfied: scikit-image>=0.12 in /opt/conda/lib/python3.10/site-packages (from lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (0.21.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.0.0)
# Collecting outcome (from trio~=0.17->selenium<=4.2.0,>=3.141.0->dash[testing]->pycaret[full])
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<=4.2.0,>=3.141.0->dash[testing]->pycaret[full])
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in /opt/conda/lib/python3.10/site-packages (from urllib3->pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (23.2.0)
# Collecting urllib3-secure-extra (from urllib3->pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full])
#   Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from urllib3->pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret[full]) (1.7.1)
# Requirement already satisfied: appdirs~=1.4.3 in /opt/conda/lib/python3.10/site-packages (from fs->triad>=0.9.1->fugue>=0.8.0->pycaret[full]) (1.4.4)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.2.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.5.13)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (2023.4.12)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime>=0.1.1.33->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]==0.4.4->interpret>=0.2.7->pycaret[full]) (0.2)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (21.2.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.4.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (6.5.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[full]) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (2.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat>=4.2.0->pycaret[full]) (1.2.3)
# Building wheels for collected packages: pyod, fugue-sql-antlr, ffmpy
# done
#   Created wheel for pyod: filename=pyod-1.1.1-py3-none-any.whl size=190078 sha256=33fbc2e9ba2780bf95202e73f8bcdbe7b3948a76b8eeb8ecad3d51d497ca50a6
#   Stored in directory: /root/.cache/pip/wheels/a3/42/d7/48a53ffc1466bd63932f28583c64ebf442114db14a0bfa8c95
# done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.8-py3-none-any.whl size=158210 sha256=2a71a2b4869f78c6be5be9c6492d1784c78a52ac079a63c72a97eb3af0442bfa
#   Stored in directory: /root/.cache/pip/wheels/a4/2b/3e/8ac985ad100a8f27de940864344fe14f47bc3d2fed7f29bf70
# done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=c6da0125201e8c9c531d3da158e5d42e5582af32f8ca636f5a84939d842e3369
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built pyod fugue-sql-antlr ffmpy
# Installing collected packages: urllib3-secure-extra, treeinterpreter, trace-updater, pytz, kaleido, interpret-core, ffmpy, dash-testing-stub, dash-table, dash-html-components, dash-core-components, colour, antlr4-python3-runtime, zope.interface, zope.event, xmltodict, wtforms, wsproto, waitress, tsdownsample, sqlalchemy, semantic-version, scipy, scikit-base, schemdraw, querystring-parser, python-multipart, oyaml, outcome, nltk, m2cgen, importlib-metadata, gunicorn, fs, ansi2html, trio, percy, pandas, httpcore, gevent, Flask, databricks-cli, dask, botocore, trio-websocket, triad, sktime, skope-rules, SALib, pyod, prometheus-flask-exporter, httpx, Flask-WTF, fairlearn, dtreeviz, distributed, dash, tune-sklearn, pmdarima, plotly-resampler, mlflow, gradio-client, fugue-sql-antlr, flask-simplelogin, evidently, dash-cytoscape, dash-bootstrap-components, dash-auth, adagio, tbats, selenium, qpd, moto, jupyter-dash, gradio, interpret, fugue, explainerdashboard, statsforecast, pycaret
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3
#     Uninstalling pytz-2023.3:
#       Successfully uninstalled pytz-2023.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.17
#     Uninstalling SQLAlchemy-2.0.17:
#       Successfully uninstalled SQLAlchemy-2.0.17
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.2
#     Uninstalling scipy-1.11.2:
#       Successfully uninstalled scipy-1.11.2
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.7.0
#     Uninstalling importlib-metadata-6.7.0:
#       Successfully uninstalled importlib-metadata-6.7.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 2.3.3
#     Uninstalling Flask-2.3.3:
#       Successfully uninstalled Flask-2.3.3
#   Attempting uninstall: dask
#     Found existing installation: dask 2023.9.0
#     Uninstalling dask-2023.9.0:
#       Successfully uninstalled dask-2023.9.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.31.17
#     Uninstalling botocore-1.31.17:
#       Successfully uninstalled botocore-1.31.17
#   Attempting uninstall: distributed
#     Found existing installation: distributed 2023.9.0
#     Uninstalling distributed-2023.9.0:
#       Successfully uninstalled distributed-2023.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.4 requires botocore<1.31.18,>=1.31.17, but you have botocore 1.29.165 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# beatrix-jupyterlab 2023.621.222118 requires jupyter-server~=1.16, but you have jupyter-server 2.6.0 which is incompatible.
# fitter 1.6.0 requires pandas<3.0.0,>=2.0.3, but you have pandas 1.5.3 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.50 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# opentelemetry-api 1.18.0 requires importlib-metadata~=6.0.0, but you have importlib-metadata 5.2.0 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.10.1 which is incompatible.
# yapf 0.40.1 requires importlib-metadata>=6.6.0, but you have importlib-metadata 5.2.0 which is incompatible.
# Successfully installed Flask-2.2.3 Flask-WTF-1.2.1 SALib-1.4.7 adagio-0.2.4 ansi2html-1.8.0 antlr4-python3-runtime-4.11.1 botocore-1.29.165 colour-0.1.5 dash-2.14.1 dash-auth-2.0.0 dash-bootstrap-components-1.5.0 dash-core-components-2.0.0 dash-cytoscape-0.3.0 dash-html-components-2.0.0 dash-table-5.0.0 dash-testing-stub-0.0.2 dask-2023.7.0 databricks-cli-0.18.0 distributed-2023.7.0 dtreeviz-2.2.2 evidently-0.2.8 explainerdashboard-0.4.3 fairlearn-0.7.0 ffmpy-0.3.1 flask-simplelogin-0.1.2 fs-2.4.16 fugue-0.8.6 fugue-sql-antlr-0.1.8 gevent-23.9.1 gradio-3.50.2 gradio-client-0.6.1 gunicorn-20.1.0 httpcore-0.18.0 httpx-0.25.0 importlib-metadata-5.2.0 interpret-0.4.4 interpret-core-0.4.4 jupyter-dash-0.4.2 kaleido-0.2.1 m2cgen-0.10.0 mlflow-1.30.1 moto-4.2.7 nltk-3.8.1 outcome-1.3.0.post0 oyaml-1.0 pandas-1.5.3 percy-2.0.2 plotly-resampler-0.9.1 pmdarima-2.0.4 prometheus-flask-exporter-0.23.0 pycaret-3.1.0 pyod-1.1.1 python-multipart-0.0.6 pytz-2022.7.1 qpd-0.4.4 querystring-parser-1.2.4 schemdraw-0.15 scikit-base-0.5.2 scipy-1.10.1 selenium-4.2.0 semantic-version-2.10.0 skope-rules-1.0.1 sktime-0.21.1 sqlalchemy-1.4.50 statsforecast-1.5.0 tbats-1.1.3 trace-updater-0.0.9.1 treeinterpreter-0.2.3 triad-0.9.1 trio-0.22.2 trio-websocket-0.11.1 tsdownsample-0.1.2 tune-sklearn-0.4.6 urllib3-secure-extra-0.1.0 waitress-2.1.2 wsproto-1.2.0 wtforms-3.1.0 xmltodict-0.13.0 zope.event-5.0 zope.interface-6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
corn_df.columns
# Out:
# Index(['Year', 'state', 'max_humidity 1', 'max_humidity 2', 'max_humidity 3',
#        'max_humidity 4', 'max_humidity 5', 'max_humidity 6', 'max_humidity 7',
#        'max_humidity 8',
#        ...
#        'wind_speed 44', 'wind_speed 45', 'wind_speed 46', 'wind_speed 47',
#        'wind_speed 48', 'wind_speed 49', 'wind_speed 50', 'wind_speed 51',
#        'wind_speed 52', 'Corn_Yield'],
#       dtype='object', length=471)

# %%
corn_df.shape
# Out:
# (533, 471)

# %%
from pycaret.regression import *
s = setup(data = corn_df, target = 'Corn_Yield', session_id=123)
# Out:
# <style type="text/css">
# #T_741e9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_741e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_741e9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_741e9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_741e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_741e9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_741e9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_741e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_741e9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_741e9_row1_col1" class="data row1 col1" >Corn_Yield</td>
#     </tr>
#     <tr>
#       <th id="T_741e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_741e9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_741e9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_741e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_741e9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_741e9_row3_col1" class="data row3 col1" >(533, 471)</td>
#     </tr>
#     <tr>
#       <th id="T_741e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_741e9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_741e9_row4_col1" class="data row4 col1" >(533, 483)</td>
#     </tr>
#     <tr>
#       <th id="T_741e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_741e9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T